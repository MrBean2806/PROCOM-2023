# %% [markdown]
# # Comentarios

# %%
# Primeros comandos de Python
# Comentarios de una sola linea
"""
Comentarios multilinea
Comentarios multilinea
"""

# %% [markdown]
# # Importando librerías

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Asignaciones basicas

# %%
d_num  = 5
d_flt  = 5.
d_str  = 'texto'
d_numv = [0,1,2,3]
d_strv = ['Sol','Luna','Tierra']

# %% [markdown]
# # Imprimir en pantalla

# %%
print('#'*20)
print('#############################################')
print('Este numero es: ',d_num)
print(d_str)
print('Lista: ',d_numv,'\t','Un dato: ',d_numv[0])
print('Lista: ',d_strv,'\t','Un dato: ',d_strv[2])
print('El valor d_strv: %s'%d_strv[0])
print('El valor d_strv: %.2f'%(12.5555))
print('El valor d_strv: {:.2f}'.format(12.5555))
print('El valor d_strv: {}'.format(12.5555))
print('#############################################')

# %% [markdown]
# # Operaciones

# %%
print('#############################################')
suma     = 3 + d_num;    print('Sum:',suma)
resta    = suma - 15;    print('Res:',resta)
prod     = suma * resta; print('Pro:',prod)
div      = 6/2;          print('Div:',div,'\tTipo:',type(div))
div_e    = 6//2;         print('Div entera:',div_e,'\tTipo:',type(div_e))
modulo   = 8 % 3;        print('Mod:',modulo)
strv     = 'day'*2;      print(strv)        # Se repite la palabra
lists    = d_numv * 3;   print(lists)       # Se repite la lista
print('#############################################')

# %% [markdown]
# # Condicional y métodos de generación de strings

# %%
print ('#############################################')
ptr = 0
if(ptr==0):
    print ("Este numero es %d"%ptr)
elif(ptr==1):
    print ("Este numero es %d"%ptr + " no esperado")
elif(ptr>20 and ptr<=30):
    print ('>>>>>>>: ',ptr )
else:
    print ('El valor es %d %s'%(ptr,"no esperado"))
print ('#############################################')

# %% [markdown]
# # Iterativo

# %%
print ('#############################################')
for ptr in range(8):
    print (ptr,end=' ')
print()
print ('#############################################')
print ('#############################################')
for ptr in d_strv:
    print (ptr ,end=' ')
print()
print ('#############################################')

# %% [markdown]
# # Operaciones con vectores (np.ndarray)

# %%
print('#############################################')
t_array = np.array([0,1,2,3]);                   print(t_array)
t_array = np.arange(0,5,2);                      print(t_array)     #arrange(start, stop, step=1) 
t_array = np.arange(0,5)*3;                      print(t_array)
t_array = np.arange(0,5)//3;                     print(t_array)
t_array = np.arange(0,5)/3;                      print(t_array)
t_array = np.arange(0,5)*np.arange(0,5);         print(t_array)
t_array = np.dot(np.arange(0,5),np.arange(0,5)); print(t_array)

t_matrix = np.dot(np.matrix([[0, 1, 2, 3],[0, 1, 2, 3]]),
                  np.matrix([[0, 1], [2, 3],[0, 1], [2, 3]])); print(t_matrix)
print(type(t_matrix))
print('#############################################')

# %% [markdown]
# # Seleccion en vectores

# %%
print ('#############################################')
t0     = np.arange(1,5);                        print (t0)  

t0[0]  = 25;                                    print (t0)                          
t0[len(t0)-1] = 100;                            print (t0)
t0[-1] = 45;                                    print (t0)  #selecionar ultimo elemento                          
t0[:]  = 1;                                     print (t0)  #seleccionar todos los elementos
t0[0:2]= 3;                                     print (t0)  #seleccionar un rango de elementos
t0[3:5]= 2;                                     print (t0)  
t0[0:6]= 5;                                     print (t0)

t0     = np.arange(0,5);                        print (t0)
c0 = t0>2;                                      print (c0)  #devuelve un arreglo con los elementos que cumplen la condicion
t1 = t0[c0];                                    print (t1)
t2 = t0[t0!=2];                                 print (t2)

# print (len(t0),'\n',np.size(t0),'\n',np.size(t_matrix))
# print (t_matrix)
# print (np.shape(t_matrix))  #tamaño en cada dimension
print ('#############################################')

# %% [markdown]
# # Matrices

# %% [markdown]
# **:** selecciona todos los elementos
#
# **x:** selecciona desde x hasta el final
#
# **:x** selecciona desde el principio hasta x
#
# **start:stop:step**

# %%
print ('#############################################')
t1         = np.zeros((1,5)); print (t1)    #zeros(filas, columnas)
print(type(t1))
t1         = np.ones((3,5)) ; #print (t1)
t1         = np.zeros((5,5)); #print (t1)

t1[:,3]    = 1;               print (t1)
t1[0:5:2,:2]  = 2;            print (t1)
t1         = t1 + 5;          print (t1)
t1         = t1 - 5;          print (t1)
t1         = t1 * 5;          print (t1)
t1         = t1 / 5;          print (t1)
t2         = t1 * t1;         print (t2)
t2         = np.dot(t1, t1);  print (t2)
r,c=np.shape(t1);             print (r,c)
print ('#############################################')

# %% [markdown]
# # Iterativo

# %%
print ('#############################################')
t_vec = np.arange(0.,25.1,1.)
print (t_vec)
for ptr in range(len(t_vec)-1,-1,-1):   #range(start, stop, step)
    print (t_vec[ptr])
print ('#############################################')

# %% [markdown]
# ## Ejemplo

# %%
print('#############################################')
count = 0
lista = []
for ptr in t_vec[0:5]:
    print (ptr)
    count += 1
    t_vec[count]=ptr+2
    lista.append(ptr+2)
print("Vec>> ",t_vec[1:6])
print("List>> ",lista)
print('#############################################')

# %% [markdown]
# ## Iterativo

# %%
print('#############################################')
ptr = 0
o_data = 0
while(ptr < len(t_vec)):
    o_data += t_vec[ptr]
    ptr    += 1
print(o_data)
print('#############################################')

# %% [markdown]
# # Igualdad en float

# %%
a=2/3.1
b=0.2/0.31
print (a==b)

# %%
print(a)
print(b)

# %%
print('{:.22f}'.format(a))
print('{:.22f}'.format(b))

# %%
def are_equal(n1,n2):
    return abs(n1-n2)<0.0000001

print(are_equal(a,b))

# %%
import math
print(math.isclose(a, b, abs_tol=0.0000001))

# %% [markdown]
# # Definicion de funciones

# %%
def producto(a,b):
    c = a * b
    return c

c = producto(2,2)
print (c)

# %% [markdown]
# ## Pasaje de argumentos mutables e inmutables

# %%
def funcion(val):
    val=4
    print(val)
    return

x=10
funcion(x)
print(x)

# %%
def funcion2 (lista):
    lista.append(40)
    #lista[0] = 8
    #lista = [8]
    #print(lista)
    return

x=[10,20,30]
funcion2(x)
print(x)

# %%
def funcion3 (vector):
    vector[0] = 8
    #vector = np.array([8])
    #print(vector)
    return

x=np.array([10,20,30])
funcion3(x)
print(x)

# %% [markdown]
# # Shallow copy - Deep copy

# %%
colores1 = ["rojo", "azul"]
colores2 = colores1
print(colores1)
print(colores2)
# Out:
# ['rojo', 'azul']
# ['rojo', 'azul']

# %%
colores2[0]="amarillo"
print(colores1)
print(colores2)
# Out:
# ['amarillo', 'azul']
# ['amarillo', 'azul']

# %%
colores1 = ["rojo", "azul"]
colores2 = colores1

colores2=["amarillo","verde"]
print(colores1)
print(colores2)
# Out:
# ['rojo', 'azul']
# ['amarillo', 'verde']

# %%
colores1 = ["rojo", "azul"]
colores2 = colores1[:]

colores2[0]="amarillo"
print(colores1)
print(colores2)

# %%
colores1 = ["rojo", "azul"]
colores2 = colores1.copy()

colores2[0]="amarillo"
print(colores1)
print(colores2)

# %%
#Con vectores

numeros1 = np.arange(0,4)
numeros2 = numeros1
numeros2[0:2] = 33
print(numeros1)
print(numeros2)

numeros1 = np.arange(0,4)
numeros2 = numeros1.copy() #deep copy
numeros2[0:2] = 33
print(numeros1)
print(numeros2)

# %% [markdown]
# # Importando módulos

# %%
import sys
print(sys.path)

# %%
import hola
hola.decirHola("Juan")
#from hola import decirHola
#decirHola("Juan")

# %% [markdown]
# # Entrada de datos

# %%
a = input('Ingrese Opcion')
print (a)

# %% [markdown]
# # String Split

# %%
text = 'Hola a todos'

# Splits at space
print(text.split())

word = 'Hola, a, todos'

# Splits at ','
print(word.split(','))

word = 'Hola:a:todos'

# Splitting at ':'
print(word.split(':'))

word = 'CatBatSatFatOr'

# Splitting at t
print(word.split('t'))

# %% [markdown]
# # String Slice
# **start:** Represents the starting index value for the slicing. It’s optional and it defaults to None(beginning of the string at index 0).
# **stop:** Represents the ending index value for the slicing. It’s mandatory.
# **step:** Represents the steps between each index for slicing. It’s optional and it may be an increment step(positive number) or decrement step(negative number).

# %%
greetings = "Hello World!"   # define a string
s = slice(1,15,2)    # define our slicing object
print(greetings[s])      # apply slicing 
print(greetings)

# %% [markdown]
# # String Join

# %%
# Joining with empty separator
list1 = ['Hola', 'a', 'todos']
print(" ".join(list1))

# Joining with string
list1 = " join "
print("$".join(list1))

# %%
def armarTrama(device, data):
    cabecera = 4*['0']
    trama = []

    cabecera [0] = "101"  
    if(len(data) < 2**4-1):         #trama corta
        print("trama corta")
        cabecera[0] += '0'          # L/S = 0
        cabecera[0] += format(len(data), '04b')     #agrego el tamaño del dato en bin (4 bits)
    elif(len(data) < 2**16-1):      #trama larga
        # print("trama larga")
        cabecera[0] += '1'          # L/S = 1
        cabecera[0] += '0000'       # S.size = 0
        aux = format(len(data), '016b')
        cabecera[1] = aux[0:8]      #L.size (L)
        cabecera[2] = aux[8:16]     #L.size (H)
    cabecera[3] = format(int(device), '08b')    #Device
    fin = "010" + cabecera[0][3:8] 
    # print(cabecera)
    for ptr in range(len(cabecera)):
        # print(chr(int(cabecera[ptr],2)))
        trama.append(chr(int(cabecera[ptr],2)))     #guardo los bits de la cabecera en un solo byte 
    trama.append(data)
    trama.append(chr(int(fin,2)))
    # print(trama)
    return trama

# %%
cabecera =  ['10110000', '00000000', '00010110', '00000000']
    trama_tx = bytearray(5)
    for ptr in range(len(cabecera)):
        trama_tx[ptr] = int(cabecera[ptr],2)
        print(trama_tx[ptr])
    print(trama_tx)
    print(trama_tx[0])
    #envio del comando
    # for ptr in range(len(trama_tx)):
    #     # ser.write(trama_tx[ptr].encode())  #unicode -> bytes
    #     ser.write(trama_tx[ptr]) 
    #     print(trama_tx[ptr])
    ser.write(trama_tx) 

    #recepcion del comando
    trama_rx = bytearray(1)
    while ser.inWaiting() > 0:
        # trama_rx += ser.read(2).decode()
        trama_rx += ser.read(1)
    print("Trama recibida = ", trama_rx)
    for ptr in range(len(trama_rx)):
        print(trama_rx[ptr])

# %% [markdown]
# # Sandbox
# PROBAR CAMBIANDO USANDO TRAMA COMO UN STRING EN LUGAR DE UNA LISTA DE STRINGS

# %%
# y = chr(65)  #le paso codigo ascii (int) y guarda el valor char
# print(y)
# x = ord('A')    #le paso un string con un caracter ascii y devuelve su representacion entera
# print(x)
# device, data (strings)
cabecera = 4*['0']      #lista de strings
trama = []
device = "25"    
data = "CalculadoraCalculadora"
cabecera [0] = "101" 

if(len(data) < 2**4-1): #trama corta
    print("trama corta")
    cabecera[0] += '0'
    cabecera[0] += format(len(data), '04b')     #agrego el tamaño del dato en bin (4 bits)
elif(len(data) < 2**16-1):  #trama larga
    print("trama larga")
    cabecera[0] += '1'
    cabecera[0] += '0000'
    aux = format(len(data), '016b')
    cabecera[1] = aux[0:8]
    cabecera[2] = aux[8:16]
cabecera[3] = format(int(device), '08b') 
fin = "010" + cabecera[0][3:8] 
print("cabecera = ", cabecera)
# trama.append(cabecera)
# trama = cabecera + data + fin
# print(trama)
for ptr in range(len(cabecera)):
    # print(chr(int(cabecera[ptr],2)))
    trama.append(chr(int(cabecera[ptr],2)))     #guardo los bits de la cabecera en un solo byte 
    # aux = int(cabecera[ptr],2)
    # trama.append(bytes([aux]))     #guardo los bits de la cabecera en un solo byte 
trama.append(data)
trama.append(chr(int(fin,2)))
print("trama = ", trama)

# for ptr in range(len(trama)):
#     print(trama[ptr])

num = '10101100'
char  = chr(int(num,2))


# trama_str =  ['10110000', '00000000', '00010110', '00000000']
# aux = 4*[0]
# for ptr in range(len(trama_str)):
#     aux[ptr] = int(trama_str[ptr],2)
# trama_tx = bytearray(aux)
# b = bytearray("Calculadora", 'utf-8')
# c = trama_tx + b
# print(b[0])
# print(c)
# print(b[0])
# print(len(b))


# trama = ['°', '\x00', '\x18', '\x00']
# binary_data = bytes([66])  # ASCII values for A, B, C
# text = binary_data.decode('utf-8')
# print(text)

# %%
cabecera = 4*['0']      #lista de strings
device = "25"    
data = "CalculadoraCalculadora"
cabecera [0] = "101" 

cabecera [0] = "101"  
if(len(data) < 2**4-1):         #trama corta
    print("trama corta")
    cabecera[0] += '0'          # L/S = 0
    cabecera[0] += format(len(data), '04b')     #agrego el tamaño del dato en bin (4 bits)
elif(len(data) < 2**16-1):      #trama larga
    # print("trama larga")
    cabecera[0] += '1'          # L/S = 1
    cabecera[0] += '0000'       # S.size = 0
    aux = format(len(data), '016b')
    cabecera[1] = aux[0:8]      #L.size (L)
    cabecera[2] = aux[8:16]     #L.size (H)
cabecera[3] = format(int(device), '08b')    #Device
fin = "010" + cabecera[0][3:8] 
# print(cabecera)

aux = []
for ptr in range(len(cabecera)):
    aux.append(int(cabecera[ptr],2))    #arreglo de la representacion entera de los bytes de la trama
trama = bytearray(aux)               #genero un bytearray con esos enteros
trama += bytearray(data, 'utf-8')
trama += bytearray([int(fin,2)])
print("trama = ", trama)
# print(chr(trama[4]))

# %%
import numpy as np

# seed = 0x1AA
# lfsr = seed
# i = 0

# newbit = ((lfsr>>4) ^ (lfsr>>8)) & 1 
# print('newbit: ', bin(newbit))
# print('lfsr', bin(lfsr))
# lfsr = ((lfsr << 1) | newbit) & 0x1FF
# print('lfsr', bin(lfsr))

seed =[1,1,0,1,0,1,0,1,0]
lfsr = np.array(seed)

# seed = seed[::-1]
print('seed', seed)
print('lfsr', lfsr)

i = 0
while True:
    newbit = (lfsr[8-4] ^ lfsr[8-8])
    # print(lfsr[8-4], lfsr[8-8])
    # print('newbit: ', newbit)
    # print('lfsr', lfsr)
    # print('lfsr', lfsr[1:])
    lfsr[0:-1] = lfsr[1:]
    lfsr[8-0] = newbit
    print('lfsr', lfsr)
    print('seed', seed)
    i = i + 1
    if((lfsr == seed).all()):
        print("La secuencia se repitió %d veces"%i)
        break
    
    
# while True:
#     newbit = ((lfsr>>4) ^ (lfsr>>8)) & 1 
#     lfsr = ((lfsr << 1) | newbit) & 0x1FF
#     print(lfsr)
#     i = i + 1
#     if(lfsr == seed):
#         print("La secuencia se repitió %d veces"%i)
#         break
# Out:
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [1 1 0 1 0 1 0 1 0]
# lfsr [1 0 1 0 1 0 1 0 1]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 1 0 1 0 1 0 1 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [1 0 1 0 1 0 1 0 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 1 0 1 0 1 0 0 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [1 0 1 0 1 0 0 0 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 1 0 1 0 0 0 0 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [1 0 1 0 0 0 0 0 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 1 0 0 0 0 0 0 1]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [1 0 0 0 0 0 0 1 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 0 0 0 0 0 1 0 1]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 0 0 0 0 1 0 1 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 0 0 0 1 0 1 0 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 0 0 1 0 1 0 0 1]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 0 1 0 1 0 0 1 0]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# lfsr [0 1 0 1 0 0 1 0 1]
# seed [1, 1, 0, 1, 0, 1, 0, 1, 0]
# ...

# %%
import numpy as np

seed_I = [1,1,0,1,0,1,0,1,0]
prbsTx_I = np.array(seed_I)

for n in range(2**9):
    s = ''.join(str(e) for e in prbsTx_I)
    print(hex(int(s,2)))
    newbit = prbsTx_I[8] ^ prbsTx_I[4]  
    prbsTx_I = np.roll(prbsTx_I,1) 
    prbsTx_I[0] = newbit
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\agusb\OneDrive\Escritorio\PROCOM\tp1\intro_python.ipynb Cell 64 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/agusb/OneDrive/Escritorio/PROCOM/tp1/intro_python.ipynb#Y121sZmlsZQ%3D%3D?line=5'>6</a> for n in range(2**9):
#       <a href='vscode-notebook-cell:/c%3A/Users/agusb/OneDrive/Escritorio/PROCOM/tp1/intro_python.ipynb#Y121sZmlsZQ%3D%3D?line=6'>7</a>     s = ''.join(str(e) for e in prbsTx_I)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/agusb/OneDrive/Escritorio/PROCOM/tp1/intro_python.ipynb#Y121sZmlsZQ%3D%3D?line=7'>8</a>     print(int(int(s,2),16))
#       <a href='vscode-notebook-cell:/c%3A/Users/agusb/OneDrive/Escritorio/PROCOM/tp1/intro_python.ipynb#Y121sZmlsZQ%3D%3D?line=8'>9</a>     newbit = prbsTx_I[8] ^ prbsTx_I[4]
# ...
